# %% [markdown]
# <a href="https://colab.research.google.com/github/DSabarish/Practice/blob/main/Basic_Prob_and_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import expon
from scipy.stats import norm
import math as m
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 100
k = 25
p = 0.3

binom.pmf(k, n, p)
# Out:
# 0.04955992276217036

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 80
mu = 70
std_dev = 3

z = (x - mu) / std_dev
z
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
k = 5
n = 20
p = 0.1

probability = binom.pmf(k, n, p)
probability
# Out:
# 0.031921361119954424

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = 65
mu = 60
std_dev = 5

z = (X - mu) / std_dev
z
# Out:
# 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
3*4*2
# Out:
# 24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
k = 2
n = 8
p = 0.5

probability = binom.cdf(k, n, p)
probability
# Out:
# 0.14453125

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
